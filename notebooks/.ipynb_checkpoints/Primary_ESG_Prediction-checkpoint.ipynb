# %% [markdown]
# # Instalação das Bibliotecas e Configurações Iniciais

# %%
# ===================================================================='
# CÉLULA 1: INSTALAÇÃO E IMPORTAÇÕES
# ===================================================================='
# Primeiro, garantimos que todas as bibliotecas necessárias estão instaladas.
# O comando '!' permite executar comandos do terminal diretamente no notebook.
# '--quiet' faz a instalação ser mais limpa, sem mostrar muitas mensagens.
# !pip install yfinance pandas scikit-learn matplotlib xgboost ta --user --quiet

# Agora, importamos as ferramentas que vamos usar no projeto.
import numpy as np
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta
import ta  # Biblioteca para Análise Técnica (cálculo de indicadores)

# Ferramentas de Machine Learning
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
import xgboost as xgb

# Ferramentas para visualização e avisos
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore') # Ignora avisos para manter a saída limpa

# %% [markdown]
# # Configuração dos Ativos

# %%
# ===================================================================='
# CÉLULA 2: CONFIGURAÇÃO DOS ATIVOS
# ===================================================================='
# Este dicionário funciona como o "cérebro" do nosso sistema.
# Para cada ativo (ex: "VALE3.SA"), definimos quais fatores econômicos
# são mais relevantes para ele. Isso torna nosso modelo adaptativo.
# Por exemplo, para a Vale, olhamos o preço do Ouro, enquanto para o Itaú,
# olhamos o índice de volatilidade VIX.

CONFIG_ATIVOS = {
    "VALE3.SA": {
        "setor": "Mineração",
        "fatores": ['^BVSP', 'CL=F', 'BRL=X', 'GC=F', 'SPY', 'IEF'],
        "nomes_fatores": ['Ibovespa', 'Petroleo', 'Cambio', 'Ouro', 'SP500', 'IEF_10Y']
    },
    "ITUB4.SA": {
        "setor": "Bancário",
        "fatores": ['^BVSP', 'BRL=X', 'IEF', '^VIX', 'SPY'],
        "nomes_fatores": ['Ibovespa', 'Cambio', 'IEF_10Y', 'VIX', 'SP500']
    },
    "LREN3.SA": {
        "setor": "Varejo",
        "fatores": ['^BVSP', 'BRL=X', 'SPY'],
        "nomes_fatores": ['Ibovespa', 'Cambio', 'SP500']
    }
}

# %% [markdown]
# # Funções de Coleta e Preparação dos Dados

# %%
# ===================================================================='
# CÉLULA 3: FUNÇÕES DE DADOS
# ===================================================================='

# Função 1: Coleta os dados históricos do mercado usando a biblioteca yfinance.
def coletar_dados(ticker, fatores, nomes_fatores, start, end):
    print(f"--- Coletando dados para {ticker} ---")
    todos_tickers = list(set([ticker] + fatores))
    # 'auto_adjust=False' para obter os preços de Abertura, Máxima, Mínima, etc.
    dados = yf.download(todos_tickers, start=start, end=end, progress=False, auto_adjust=False)

    if dados.empty:
        print(f"Erro: Falha geral no download para {ticker}.")
        return pd.DataFrame()

    # Organiza os dados em uma tabela (DataFrame) única para o ativo principal.
    df = pd.DataFrame(index=dados.index)
    df['Abertura'] = dados['Open'][ticker]
    df['Maxima'] = dados['High'][ticker]
    df['Minima'] = dados['Low'][ticker]
    df['Preco_Fechamento'] = dados['Close'][ticker]
    df['Volume'] = dados['Volume'][ticker]

    # Adiciona as colunas dos fatores econômicos.
    for fator, nome in zip(fatores, nomes_fatores):
        if fator in dados['Close'].columns:
            df[nome] = dados['Close'][fator]
        else:
            print(f"Aviso: Não foi possível baixar o fator '{nome}' ({fator}).")

    return df

# Função 2: Cria os "fatores" (features) que o modelo de IA usará para aprender.
def engenharia_fatores(df):
    print("--- Realizando engenharia de fatores ---")
    # Fatores básicos de retorno e volatilidade.
    df['Retorno_1d'] = df['Preco_Fechamento'].pct_change()
    df['Retorno_Futuro'] = df['Preco_Fechamento'].pct_change().shift(-1) # O que queremos prever
    df['Momentum_5d'] = df['Preco_Fechamento'].pct_change(5)
    df['Volatilidade_10d'] = df['Retorno_1d'].rolling(window=10).std()

    # Indicadores técnicos clássicos (RSI, Médias Móveis).
    df['RSI_14d'] = ta.momentum.RSIIndicator(close=df['Preco_Fechamento'], window=14).rsi()
    df['SMA_10_50_Ratio'] = ta.trend.SMAIndicator(df['Preco_Fechamento'], window=10).sma_indicator() / ta.trend.SMAIndicator(df['Preco_Fechamento'], window=50).sma_indicator()

    # Limpeza final e segura: remove as linhas do início que ficaram com dados vazios (NaN).
    df.dropna(inplace=True)

    if df.empty:
        print("ERRO CRÍTICO: DataFrame ficou vazio após a engenharia de fatores.")
        return df

    # Cria a variável "alvo": 1 se o retorno futuro for maior que 0.2%, 0 caso contrário.
    df['Target_Compra'] = (df['Retorno_Futuro'] > 0.002).astype(int)
    return df

# %%
# Funções de Machine Learning

# %%
# ===================================================================='
# CÉLULA 4: FUNÇÕES DE MACHINE LEARNING
# ===================================================================='

# Função 3: Treina e otimiza o modelo de Inteligência Artificial.
def otimizar_modelo(df, features, target):
    print("--- Otimizando modelo com GridSearchCV e TimeSeriesSplit ---")
    X = df[features] # X são os fatores (features) que o modelo usa para aprender.
    y = df[target]   # y é o alvo (target) que o modelo tenta prever.

    if X.empty:
        print("Erro: Conjunto de features está vazio antes da otimização.")
        return None, None

    # Normaliza os dados. Isso ajuda o modelo a aprender melhor.
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # TimeSeriesSplit é crucial para dados financeiros. Ele garante que o modelo
    # seja treinado no passado para prever o futuro, evitando erros lógicos.
    tscv = TimeSeriesSplit(n_splits=3)

    # Define os parâmetros que queremos testar no modelo (XGBoost).
    param_grid_xgb = {
        "max_depth": [3, 5],
        "n_estimators": [100, 200],
        "learning_rate": [0.05, 0.1]
    }

    # GridSearchCV testa todas as combinações de parâmetros e encontra a melhor.
    # NOVO: Adicionado 'random_state=42' para garantir que os resultados sejam sempre os mesmos.
    xgb_model = xgb.XGBClassifier(objective='binary:logistic', use_label_encoder=False, verbosity=0, eval_metric='logloss', random_state=42)
    gsearch_xgb = GridSearchCV(xgb_model, param_grid_xgb, cv=tscv, scoring='accuracy', n_jobs=-1)
    gsearch_xgb.fit(X_scaled, y)

    print(f"Melhores parâmetros encontrados: {gsearch_xgb.best_params_}")
    return gsearch_xgb.best_estimator_, scaler

# Função 4: Usa o modelo treinado para fazer as previsões de compra.
def fazer_predicoes(modelo, scaler, df, features):
    X = df[features]
    X_scaled = scaler.transform(X)
    # Pega a probabilidade do modelo de o alvo ser "1" (compra).
    proba = modelo.predict_proba(X_scaled)[:, 1]
    # Gera o sinal final: compra (1) se a probabilidade for maior que 55%, não compra (0) caso contrário.
    return (proba > 0.55).astype(int), proba

# %%
# Funções de Simulação (Backtesting) e Gráficos

# %%
# ===================================================================='
# CÉLULA 5: FUNÇÕES DE BACKTESTING E VISUALIZAÇÃO
# ===================================================================='

# Função 5: Simula a estratégia no passado, com regras realistas.
def backtest_com_stops(df, sinais, capital_inicial=10000, stop_loss_pct=0.02, take_profit_pct=0.04):
    print("--- Executando backtest com Stop-Loss e Take-Profit ---")
    capital = capital_inicial
    posicao = 0 # 0 = não comprado, 1 = comprado
    capitais = [] # Histórico do capital
    preco_compra = 0

    for i in range(len(df)):
        preco_atual = df['Preco_Fechamento'].iloc[i]

        # Lógica de Venda: Se estiver comprado, verifica se atingiu o stop-loss ou take-profit.
        if posicao == 1:
            retorno = (preco_atual - preco_compra) / preco_compra
            # Vende se o prejuízo for >= 2% OU se o lucro for >= 4%
            if retorno <= -stop_loss_pct or retorno >= take_profit_pct:
                capital *= (1 + retorno) # Atualiza o capital
                posicao = 0
                preco_compra = 0

        # Lógica de Compra: Se não estiver comprado e o modelo der sinal (1), compra.
        if sinais[i] == 1 and posicao == 0:
            posicao = 1
            preco_compra = preco_atual

        capitais.append(capital)

    return capitais

# Função 6: Plota o gráfico de desempenho da estratégia.
def plotar_capital(df, capital_acumulado, ticker):
    df_plot = pd.DataFrame(index=df.index)
    df_plot['Capital'] = capital_acumulado
    # Cria uma linha de benchmark (simplesmente comprar e segurar) para comparação.
    df_plot['Benchmark'] = (df['Preco_Fechamento'] / df['Preco_Fechamento'].iloc[0]) * 10000

    plt.figure(figsize=(12, 7))
    plt.plot(df_plot.index, df_plot['Capital'], label='Capital da Estratégia', color='blue')
    plt.plot(df_plot.index, df_plot['Benchmark'], label='Benchmark (Buy & Hold)', color='gray', linestyle='--')
    plt.title(f'Desempenho da Estratégia para {ticker}', fontsize=16)
    plt.xlabel('Data')
    plt.ylabel('Capital (R$)')
    plt.legend()
    plt.grid(True)
    plt.show()
